# %%
# !git clone https://github.com/Keshabkjha/DeepSeaShield.git
# Out:
# Cloning into 'DeepSeaShield'...
# remote: Enumerating objects: 3640, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3640 (delta 0), reused 0 (delta 0), pack-reused 3636 (from 1)
# Receiving objects: 100% (3640/3640), 1.60 GiB | 49.98 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Updating files: 100% (3608/3608), done.

# %%
# %cd DeepSeaShield

# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# /kaggle/working/DeepSeaShield
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 81.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 26.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [onnxscript]
# ...

# %%
# !pip install torch torchvision matplotlib opencv-python
